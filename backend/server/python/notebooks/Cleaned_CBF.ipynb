# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
import pickle

# %% [markdown]
# Loading the dataset

# %%
df = pd.read_csv("fullDataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16038 entries, 0 to 16037
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tconst                        16038 non-null  object
#  1   primaryTitle                  16038 non-null  object
#  2   startYear                     16038 non-null  int64
#  3   runtimeMinutes                16038 non-null  int64
#  4   rating                        16038 non-null  float64
#  5   primaryGenre_Adult            16038 non-null  bool
#  6   primaryGenre_Adventure        16038 non-null  bool
#  7   primaryGenre_Animation        16038 non-null  bool
#  8   primaryGenre_Biography        16038 non-null  bool
#  9   primaryGenre_Comedy           16038 non-null  bool
#  10  primaryGenre_Crime            16038 non-null  bool
#  11  primaryGenre_Documentary      16038 non-null  bool
#  12  primaryGenre_Drama            16038 non-null  bool
#  13  primaryGenre_Family           16038 non-null  bool
#  14  primaryGenre_Fantasy          16038 non-null  bool
#  15  primaryGenre_Film-Noir        16038 non-null  bool
#  16  primaryGenre_History          16038 non-null  bool
#  17  primaryGenre_Horror           16038 non-null  bool
#  18  primaryGenre_Music            16038 non-null  bool
#  19  primaryGenre_Musical          16038 non-null  bool
#  20  primaryGenre_Mystery          16038 non-null  bool
#  21  primaryGenre_News             16038 non-null  bool
#  22  primaryGenre_Reality-TV       16038 non-null  bool
#  23  primaryGenre_Romance          16038 non-null  bool
#  24  primaryGenre_Sci-Fi           16038 non-null  bool
#  25  primaryGenre_Science Fiction  16038 non-null  bool
#  26  primaryGenre_Short            16038 non-null  bool
#  27  primaryGenre_Sport            16038 non-null  bool
#  28  primaryGenre_TV Movie         16038 non-null  bool
#  29  primaryGenre_Thriller         16038 non-null  bool
#  30  primaryGenre_War              16038 non-null  bool
#  31  primaryGenre_Western          16038 non-null  bool
#  32  primaryGenre_\N               16038 non-null  bool
#  33  directors_count               16038 non-null  int64
#  34  actor1_count                  16038 non-null  int64
#  35  actor2_count                  16038 non-null  int64
# dtypes: bool(28), float64(1), int64(5), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# Scaling the features in the dataframe

# %%
#df = df.drop("primaryGenre_\\N")

# %%
df["directors_count"] *= 1
df["actor1_count"] *= 1
df["actor2_count"] *= 1
df["rating"] *= 1

# %% [markdown]
# Changing the IMDB IDs to an index

# %%
tconsts = df['tconst']
df.set_index('tconst', inplace=True)

# %% [markdown]
# Dropping non-numeric columns

# %%
non_numeric_cols = ['primaryTitle', 'startYear']
df_train = df.drop(columns=non_numeric_cols, errors='ignore')

# %% [markdown]
# Scaling the remaining features

# %%
columns_to_scale = ['runtimeMinutes', 'rating']

# Create a scaler and fit only on those columns
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_train[columns_to_scale])

# Convert scaled values back into a DataFrame
scaled_df = pd.DataFrame(scaled_features, columns=columns_to_scale, index=df_train.index)

# Keep the non-scaled one-hot encoded + other features
non_scaled_df = df_train.drop(columns=columns_to_scale)

# Combine them back
df_scaled = pd.concat([non_scaled_df, scaled_df], axis=1)

# %% [markdown]
# Training KNN model using scaled features

# %%
df_scaled.head(10)
# Out:
#            primaryGenre_Adult  primaryGenre_Adventure  primaryGenre_Animation  \
# tconst
# tt0111161               False                   False                   False
# tt0068646               False                   False                   False
# tt0468569               False                   False                   False
# tt0167260               False                    True                   False
# tt0108052               False                   False                   False
# tt0071562               False                   False                   False
# tt0050083               False                   False                   False
# tt0252487               False                   False                   False
# tt0110912               False                   False                   False
# tt0120737               False                    True                   False
#
#            primaryGenre_Biography  primaryGenre_Comedy  primaryGenre_Crime  \
# tconst
# tt0111161                   False                False               False
# tt0068646                   False                False                True
# tt0468569                   False                False               False
# tt0167260                   False                False               False
# tt0108052                    True                False               False
# tt0071562                   False                False                True
# tt0050083                   False                False                True
# tt0252487                   False                 True               False
# tt0110912                   False                False                True
# tt0120737                   False                False               False
#
#            primaryGenre_Documentary  primaryGenre_Drama  primaryGenre_Family  \
# tconst
# tt0111161                     False                True                False
# tt0068646                     False               False                False
# tt0468569                     False               False                False
# tt0167260                     False               False                False
# tt0108052                     False               False                False
# tt0071562                     False               False                False
# tt0050083                     False               False                False
# tt0252487                     False               False                False
# tt0110912                     False               False                False
# tt0120737                     False               False                False
#
#            primaryGenre_Fantasy  ...  primaryGenre_TV Movie  \
# tconst                           ...
# tt0111161                 False  ...                  False
# tt0068646                 False  ...                  False
# tt0468569                 False  ...                  False
# tt0167260                 False  ...                  False
# tt0108052                 False  ...                  False
# tt0071562                 False  ...                  False
# tt0050083                 False  ...                  False
# tt0252487                 False  ...                  False
# tt0110912                 False  ...                  False
# tt0120737                 False  ...                  False
#
#            primaryGenre_Thriller  primaryGenre_War  primaryGenre_Western  \
# tconst
# tt0111161                  False             False                 False
# tt0068646                  False             False                 False
# tt0468569                  False             False                 False
# tt0167260                  False             False                 False
# tt0108052                  False             False                 False
# tt0071562                  False             False                 False
# tt0050083                  False             False                 False
# tt0252487                  False             False                 False
# tt0110912                  False             False                 False
# tt0120737                  False             False                 False
#
#            primaryGenre_\N  directors_count  actor1_count  actor2_count  \
# tconst
# tt0111161            False                4             7            22
# tt0068646            False               14            14            11
# tt0468569            False               13            24             4
# tt0167260            False               14            16             6
# tt0108052            False               34            32             9
# tt0071562            False               14            25            16
# tt0050083            False               17            12             2
# tt0252487            False               14             9             4
# tt0110912            False               11            28             9
# tt0120737            False               14            16             6
#
#            runtimeMinutes    rating
# tconst
# tt0111161        1.096833  3.694201
# tt0068646        2.121268  3.543144
# tt0468569        1.407268  3.249903
# tt0167260        2.928398  3.247007
# tt0108052        2.742138  3.243606
# tt0071562        2.959442  3.242783
# tt0050083       -0.331167  3.235308
# tt0252487       -0.672646  3.131219
# tt0110912        1.469355  3.100000
# tt0120737        2.214398  3.099162
#
# [10 rows x 33 columns]

# %%
knn_model = NearestNeighbors(n_neighbors=11, metric='cosine')
knn_model.fit(df_scaled)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=11)

# %% [markdown]
# Function to get movie recommendations based on any number of inputs

# %%
def get_similar_movies(input_ids, k=10):
    input_vectors = df_scaled.loc[df_scaled.index.isin(input_ids)]
    if input_vectors.empty:
        raise ValueError("None of the provided movie IDs were found.")
    
    avg_vector = np.mean(input_vectors.values, axis=0).reshape(1, -1)
    distances, indices = knn_model.kneighbors(avg_vector, n_neighbors=k + len(input_ids))
    
    # Filter out inputs from result
    similar_ids = df_scaled.index[indices[0]]
    return [mid for mid in similar_ids if mid not in input_ids][:k]

# %% [markdown]
# Saving the dataframes as csv files

# %%
test_ids = ['tt0111161', 'tt0068646']  # The Shawshank Redemption & The Godfather
try:
    results = get_similar_movies(test_ids)
    print("Top similar movies:", results)
except ValueError as e:
    print("Error:", e)
# Out:
# Top similar movies: ['tt2358913', 'tt29515802', 'tt0831888', 'tt0120789', 'tt0329575', 'tt0499549', 'tt0031455', 'tt0066763', 'tt0314412', 'tt1232829']
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
df_train.reset_index(inplace=True) 
df_train.to_csv("movies.csv", index=False)
df_scaled.to_csv("scaled_features.csv", index=False)

# %% [markdown]
# Saving the model as a pkl

# %%
with open("knn_model.pkl", "wb") as f:
    pickle.dump(knn_model, f)
print("Model saved as knn_model.pkl")
# Out:
# Model saved as knn_model.pkl

# %%
#looking for sometyhing different?
#focus on age and personal info
